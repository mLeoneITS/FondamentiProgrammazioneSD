# %% [markdown]
# **Esercizio 1**: Scrivi un ciclo while che inizi dall’ultimo carattere della stringa "ananas" e proceda fino al primo carattere della stringa, stampando ogni lettera su una riga separata

# %% [markdown]
# **Esercizio 2**: Incorpora il codice visto nel punto **6.6** in una funzione chiamata “count” e rendila in grado di accettare stringhe e lettere come argomenti. Il codice in questione è il seguente:
# ```
# # word = 'banana'
# count = 0
# for letter in word:
#     if letter == 'a':
#         count = count + 1
# print(count)
# ```

# %% [markdown]
# **Esercizio 3**: esiste un metodo per le stringhe chiamato count simile alla funzione dell’esercizio al punto 6.9 (è superfluo riportare il codice della funzione)
#
# Leggi la documentazione di questo metodo su https://docs.python.org/3.5/library/stdtypes.html#string-methods e scrivi uno script che conti il numero di volte in cui la lettera a appare nella stringa “banana”.

# %% [markdown]
# **Esercizio 4**: prendi il seguente codice Python contenente una stringa
#
# `str = 'X-DSPAM-Confidence:0.8475`
#
# Usa *find* e la segmentazione delle stringhe per estrarre la porzione di stringa dopo il carattere “:” e utilizza la funzione float per convertire la stringa estratta in un numero a virgola mobile.

# %% [markdown]
# **Esercizio 5**: leggi la documentazione dei metodi di stringa su https://docs.python.org/3.5/library/stdtypes.html#string-methods
# Fai degli esperimenti con alcuni di essi per assicurarti di aver capito come funzionano.
# `strip` e `replace` sono particolarmente utili.
#
# La documentazione utilizza una sintassi che potrebbe essere fonte di confusione.
# Ad esempio, in
#
# `find(sub[, start[, end]])`
#
#  le parentesi quadre indicano argomenti opzionali. In altre parole:
#  - `sub` è necessario
#  - `start` è facoltativo
#    - ma nel caso tu lo
# inserisca, allora `end` diventa opzionale.
#   - non puoi inserire `end` senza `start`, ma se inserisci `start` puoi non inserire `end` (o meglio, se inserisci un solo parametro questo sarà sempre `start`)
