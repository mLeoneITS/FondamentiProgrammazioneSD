# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Esercizio 6**: Riscrivi il calcolo della tua retribuzione con gli straordinari pagati il 50% in più creando una funzione chiamata computepay che richieda i due parametri hours e rate. (**Hint**: *le ore di straordinario sono tutte quelle dopo le 40 "standard" settimanali*)
# ```
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0
# ```

# %% [markdown]
# **Esercizio 7**: Riscrivi lo script del capitolo precedente creando una funzione chiamata computegrade che accetta un punteggio come parametro e restituisce un voto sotto forma di stringa.
#
# ```
# Score Grade
# >= 0.9 A
# >= 0.8 B
# >= 0.7 C
# >= 0.6 D
# < 0.6 F
# Enter score: 0.95
# A
# Enter score: perfect
# Bad score
# Enter score: 10.0
# Bad score
# Enter score: 0.75
# C
# Enter score: 0.5
# F
# ```
#
#
#
# Prova ripetutamente lo script per testare diversi valori in input.
